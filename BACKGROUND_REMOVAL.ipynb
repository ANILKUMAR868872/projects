# %%
pip install rembg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # New Section

# %%
pip install pillow

# %%
pip install easygui
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from rembg import remove
from PIL import Image # pillow
import easygui

print("Please Wait...")
#input_path = easygui.fileopenbox("/desktop/Select your Image")
#Output_path = easygui.filesavebox("Where you want to save your Image")

my_img = Image.open(r'/content/input/cheg3.jpg')
print("Please Wait...")
rem = remove(my_img)
save=rem.save(r'/content/input/untitled.png')
print("Successfully Done, check your Folder")
# Out:
# Please Wait...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e8fad9f2b706> in <cell line: 9>()
#       7 #Output_path = easygui.filesavebox("Where you want to save your Image")
#       8
# ----> 9 my_img = Image.open(r'/content/input/cheg3.jpg')
#      10 print("Please Wait...")
#      11 rem = remove(my_img)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/input/cheg3.jpg'

# %% [markdown]
# *   List item
# *   List item

# %%
from ipython
